# %% [markdown]
# ### SHREYAN'S AI SKOOL

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9]
}
data = pd.DataFrame(data) 
data
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %% [markdown]
# ### SELECTION AND INDEXING OF COLUMNS

# %%
data['state']
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# Name: state, dtype: str

# %%
data[['state','year']]
# Out:
#     state  year
# 0    Ohio  2000
# 1    Ohio  2001
# 2    Ohio  2002
# 3  Nevada  2001
# 4  Nevada  2002

# %% [markdown]
# ### CREATING A NEW COLUMN

# %%
data['designation'] = ['doctor','engineer','police','IAS','athlete']

# %%
data
# Out:
#     state  year  pop designation
# 0    Ohio  2000  1.5      doctor
# 1    Ohio  2001  1.7    engineer
# 2    Ohio  2002  3.6      police
# 3  Nevada  2001  2.4         IAS
# 4  Nevada  2002  2.9     athlete

# %% [markdown]
# ### REMOVING A COLUMN

# %%
data.drop('designation',axis=1) 
# axis = 1 -> vertical like 1 need to mention to remove a column.
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
data
# Out:
#     state  year  pop designation
# 0    Ohio  2000  1.5      doctor
# 1    Ohio  2001  1.7    engineer
# 2    Ohio  2002  3.6      police
# 3  Nevada  2001  2.4         IAS
# 4  Nevada  2002  2.9     athlete

# %% [markdown]
# > only the copy me changes has been occured not in the actual DataFrame.

# %%
data.drop('designation',inplace=True, axis=1)

# %%
data
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
data.drop(['state','year'],axis=1)
# Out:
#    pop
# 0  1.5
# 1  1.7
# 2  3.6
# 3  2.4
# 4  2.9

# %%
data
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %% [markdown]
# ### SELECTING ROWS

# %%
data
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
data.loc[0]
# Out:
# state    Ohio
# year     2000
# pop       1.5
# Name: 0, dtype: object

# %%
data.loc[[0,1]]
# Out:
#   state  year  pop
# 0  Ohio  2000  1.5
# 1  Ohio  2001  1.7

# %%
data.iloc[3]
# Out:
# state    Nevada
# year       2001
# pop         2.4
# Name: 3, dtype: object

# %% [markdown]
# ### SELECTING SUBSETS OF ROWS AND COLUMNS

# %%
data
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
data.loc[[0,1]][['year','pop']]
# Out:
#    year  pop
# 0  2000  1.5
# 1  2001  1.7

# %%
data.loc[[2,3,4]][['state','year']]
# Out:
#     state  year
# 2    Ohio  2002
# 3  Nevada  2001
# 4  Nevada  2002

# %% [markdown]
# ### CONDITIONAL SELECTION

# %%
data
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
