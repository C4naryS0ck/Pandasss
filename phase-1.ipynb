# %%
import pandas as pd

# %% [markdown]
# ### Introduction to pandas Data Structures.
# #### 1. Series :
# is a one dimensional array-like object containing an array of data(of any Numpy data type) and an associated array of data labels, called its index.

# %%
obj = pd.Series([4,7,-5,3]) 
obj
# original index starting from 0 is shown
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
print(obj.values)

print(obj.index)
# Out:
# [ 4  7 -5  3]
# Index(['bob', 'steve', 'jeff', 'ryan'], dtype='str')

# %% [markdown]
# ##### Defining our own index :

# %%
obj2 = pd.Series([4,5,7,-4], index = ['a','b','c','d'])

print(obj2)
print(obj2.index)
# you can use values in the index when selecting single values or a 
# set of values.
print(obj2['a'])
print(obj2[['d','c','a']])
# Out:
# a    4
# b    5
# c    7
# d   -4
# dtype: int64
# Index(['a', 'b', 'c', 'd'], dtype='str')
# 4
# d   -4
# c    7
# a    4
# dtype: int64

# %% [markdown]
# ### Operations

# %%
print(obj2*2)
print('b' in obj2)
print('e' in obj2)
# Out:
# a     8
# b    10
# c    14
# d    -8
# dtype: int64
# True
# False

# %% [markdown]
# #### we can convert the data from python dictionary into Series.

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj3 = pd.Series(sdata)
print(obj3)
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index = states)
print(obj4)
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %% [markdown]
# #### Handling missing values:

# %%
# the value is null
print(pd.isnull(obj4))
# the values is not null
print("\nnotnull vlaues\n",pd.notnull(obj4))

print("\ninstance methods\n",obj4.isnull())
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool
#
# notnull vlaues
#  California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool
#
# instance methods
#  California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
obj3+obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %% [markdown]
# #### Give names to data's column and data's index itself.

# %%
obj4.name = 'population'
obj4.index.name = 'state'
obj4
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %% [markdown]
# #### Series Index can be altered

# %%
obj.index = ['bob','steve','jeff','ryan']
obj
# Out:
# bob      4
# steve    7
# jeff    -5
# ryan     3
# dtype: int64

# %% [markdown]
# ## 2. DataFrame
# It represents a tabular, spreadsheet-like data structure containg an ordered collection of columns, each of which can be a different value type(numeric, string, boolean, etc).
